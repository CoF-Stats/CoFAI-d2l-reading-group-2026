# %% [markdown]
# # Week 01: Chapter 3, Regression
#
# Use this starter notebook to take notes and keep track of questions as you go. You can try out the code in the chapter by opening this in a Google Colab instance. This will save it to your personal Google Drive. To make it available on GitHub, commit changes to a personal branch (see the README.md for step-by-step instructions). We will combine our notes for the main branch as a group.
