# %% [markdown]
# # Notes
#
# ## Questions
#
# - Can we come up with an example or explain this statement in greater detail?
#
#     > For example, when the label is deterministic, the covariate shift assumption will be satisfied, even when $y$ causes $\mathbf{x}$.
