# %% [markdown]
# # Notebook for testing successful spinup of GPU instance on Colab

# %%
import torch

test = torch.cuda.is_available()
print(f"GPU available: {test}")
# Out:
# GPU available: True

# %% [markdown]
# > If you get `GPU available: False`, then go to `Runtime -> Change Runtime Type` and select one of the GPU options, like 'T4'. Then rerun the cell above.
